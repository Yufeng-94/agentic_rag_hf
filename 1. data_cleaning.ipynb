# %%
import os
import json
import pandas as pd

from src.process_html import (
    record_to_document_list, 
    record_sanity_check,
    save_documents_as_jsonl,
    remove_duplicate_pages,
)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. Data Selection
#
# 1. Download file `crag_task_1_and_2_dev_v4.jsonl.bz2` from [here](https://github.com/facebookresearch/CRAG/tree/main/data)
# 2. run in terminal run `bunzip2 crag_task_1_and_2_dev_v4.jsonl.bz2`, the file will be replaced by `crag_task_1_and_2_dev_v4.jsonl`

# %%
data_dir = os.path.join('.', 'data')

# %%
# Extract metadata used as filters
path = os.path.join(data_dir, "crag_task_1_and_2_dev_v4.jsonl")

metadata_list = []
fields_to_keep = [
    'interaction_id', 
    'domain', 
    'question_type', 
    'static_or_dynamic', 
    'query',
]

with open(path, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        record = json.loads(line)

        subset = {
            field: record[field] for field in fields_to_keep
        }
        
        metadata_list.append(subset)

# %%
# Covnert metadata_list to dataframe
metadata_df = pd.DataFrame(metadata_list)
print('metadata_df shape:', metadata_df.shape)
metadata_df.head(2)
# Out:
# metadata_df shape: (2706, 5)
#                          interaction_id  domain       question_type  \
# 0  7bb29eb4-12f9-45f9-bf8a-66832b3c8962  sports     post-processing
# 1  a2486535-98e7-4876-9880-80374eac2fa8   movie  simple_w_condition
#
#   static_or_dynamic                                              query
# 0            static  how many 3-point attempts did steve nash avera...
# 1            static  what is a movie to feature a person who can cr...

# %%
metadata_df.to_csv(
    os.path.join(data_dir, "crag_v4_metadata.csv"),
    index=False,
)

# %%
# Filter samples by the following data fields
selected_domains = ["finance", "movie", "sports"]
selected_question_type = ["comparison", "aggregation", "post-processing", "multi-hop"]
selected_static_or_dynamic = ["static"]

# %%
metadata_filtered = metadata_df[
    metadata_df['domain'].isin(selected_domains) &\
    metadata_df['question_type'].isin(selected_question_type) &\
    metadata_df['static_or_dynamic'].isin(selected_static_or_dynamic)
    ]

print('metadata shape after filtering:', metadata_filtered.shape)
# Out:
# metadata shape after filtering: (264, 5)

# %%
# select 100 samples into knowledge base
knowledge_base_size = 100
knowledge_base_frac = knowledge_base_size / len(metadata_filtered)

random_seed = 42
groupby_cols = ['domain', 'question_type']

# Using stratified sampling by domain and question_type
knowledge_base_metadata = metadata_filtered.groupby(
    groupby_cols, group_keys=False
).apply(
    lambda x: x.sample(frac=knowledge_base_frac, random_state=random_seed)
)

knowledge_base_metadata.head(2)
# Out:
# /tmp/ipykernel_1170626/149959020.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ).apply(
#                            interaction_id   domain question_type  \
# 469  f068a33c-2458-4d27-8448-02906e6b5fa5  finance   aggregation
# 977  8e6f6025-d096-432b-b1d3-7fbd42007e2c  finance   aggregation
#
#     static_or_dynamic                                              query
# 469            static  how many major stock exchanges are there in th...
# 977            static  how many times did ftai aviation pay dividends...

# %%
# sanity check: make sure selected samples are in desired categories
print(knowledge_base_metadata['question_type'].unique())
print(knowledge_base_metadata['domain'].unique())
print(knowledge_base_metadata['static_or_dynamic'].unique())
# Out:
# ['aggregation' 'comparison' 'multi-hop' 'post-processing']
# ['finance' 'movie' 'sports']
# ['static']

# %%
knowledge_base_metadata.to_csv(
    os.path.join(data_dir, "kb_metadata.csv"),
    index=False,
)

# %% [markdown]
# # 2. Text Cleaning
#
# Each query relates to 5 searched web with html format. Extract content from html and parse them into a `Document` object.
#
# Create three knowledge bases for "sports", "finance", and "movie" repectively.

# %%
# create "sport" knowledge base
sports_meta = knowledge_base_metadata[knowledge_base_metadata['domain']=="sports"].copy()
print(sports_meta.shape)
# create "finance" knowledge base 
finance_meta = knowledge_base_metadata[knowledge_base_metadata['domain']=="finance"].copy()
print(finance_meta.shape)
# create "movie" knowledge base
movie_meta = knowledge_base_metadata[knowledge_base_metadata['domain']=="movie"].copy()
print(movie_meta.shape)
# Out:
# (42, 5)
# (19, 5)
# (40, 5)

# %%
sports_meta['loaded_to_kb'] = 0
finance_meta['loaded_to_kb'] = 0
movie_meta['loaded_to_kb'] = 0

# %%
documents_sports = []
documents_finance = []
documents_movie = []

path = os.path.join(data_dir, "crag_task_1_and_2_dev_v4.jsonl")

with open(path, "r", encoding="utf-8") as f:
    for idx, line in enumerate(f):
        record = json.loads(line)
        interaction_id=record['interaction_id']
        
        if record['domain'] == "sports":
            if interaction_id in sports_meta['interaction_id'].to_list():

                record_sanity_check(
                    record, 
                    sports_meta[sports_meta['interaction_id']==interaction_id].iloc[0]
                )

                # convert 5 pages into a list of Document objects
                doc_list = record_to_document_list(record)

                documents_sports += doc_list

                sports_meta.loc[(sports_meta['interaction_id']==interaction_id), 'loaded_to_kb'] += 1
            
        elif record['domain'] == "finance":
            if interaction_id in finance_meta['interaction_id'].to_list():

                record_sanity_check(
                    record, 
                    finance_meta[finance_meta['interaction_id']==interaction_id].iloc[0]
                )

                # convert 5 pages into documents
                doc_list = record_to_document_list(record)

                documents_finance += doc_list

                finance_meta.loc[(finance_meta['interaction_id']==interaction_id), 'loaded_to_kb'] += 1

        elif record['domain'] == "movie":
            if interaction_id in movie_meta['interaction_id'].to_list():

                record_sanity_check(
                    record, 
                    movie_meta[movie_meta['interaction_id']==interaction_id].iloc[0]
                )

                # convert 5 pages into documents
                doc_list = record_to_document_list(record)

                documents_movie += doc_list

                movie_meta.loc[(movie_meta['interaction_id']==interaction_id), 'loaded_to_kb'] += 1
# Out:
# WARNING:root:No text extracted from HTML content. interaction_id: 80365e4f-795e-4039-8afb-b7a8e8d54285
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 80365e4f-795e-4039-8afb-b7a8e8d54285
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 1622c61a-c116-4623-8c0c-ba7265cfab0c
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 1622c61a-c116-4623-8c0c-ba7265cfab0c
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 1622c61a-c116-4623-8c0c-ba7265cfab0c
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 3088c90a-3129-4f4a-9210-de714fbb6405
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 3088c90a-3129-4f4a-9210-de714fbb6405
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: d6ed2e39-aa0d-4d1b-a975-f400eb859e63
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 589a531e-6644-4715-98a1-c148ddc5f07f
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: c47ece5d-49ba-4ee2-ba5e-cfee323dbec0
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: c6fa5bdd-ff66-442e-96c1-41f624396b38
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: f1571f1a-8def-4587-833e-5e79a67ea063
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 34de0f5e-1961-4adb-b321-175b353c3d45
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 5242efe2-5991-4022-8d41-250b2242f6a0
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 5242efe2-5991-4022-8d41-250b2242f6a0
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 5242efe2-5991-4022-8d41-250b2242f6a0
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 47d14ce5-921b-47f3-bf8b-0c016c5c724b
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 47d14ce5-921b-47f3-bf8b-0c016c5c724b
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 94239b44-214c-436f-a6ed-134190fd3f51
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: d43aa49f-da67-42ed-91ea-adf22bc1ec62
# WARNING:trafilatura.core:discarding data: None
# WARNING:root:No text extracted from HTML content. interaction_id: 280d60d1-f2be-4895-ae73-29461c8f1b35
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 059ecf07-0a35-4b66-a4f7-8e74d292c877
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 374ec627-7e1a-4f12-9643-990ff255076b
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 26419225-82c8-4ad4-9189-a691ec5edbbe
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: b31a5f40-f448-44cd-afe8-080970f0ce90
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 960af973-1515-4d8f-8ce8-83c66cef0735
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# ERROR:trafilatura.core:empty HTML tree: None
# WARNING:trafilatura.core:discarding data: None
# ERROR:trafilatura.utils:lxml parsing failed: Document is empty
# ERROR:trafilatura.utils:lxml parser bytestring Document is empty
# WARNING:root:No text extracted from HTML content. interaction_id: 960af973-1515-4d8f-8ce8-83c66cef0735

# %%
print(len(documents_sports))
print(len(documents_finance))
print(len(documents_movie))
# Out:
# 204
# 95
# 179

# %%
# get only unique pages, remove duplicate url
documents_sports = remove_duplicate_pages(documents_sports)
documents_finance = remove_duplicate_pages(documents_finance)
documents_movie = remove_duplicate_pages(documents_movie)

print(len(documents_sports))
print(len(documents_finance))
print(len(documents_movie))
# Out:
# WARNING:root:Duplicate or missing URL found: https://www.britannica.com/biography/Steve-Nash
# WARNING:root:Duplicate or missing URL found: https://www.basketball-reference.com/players/d/davisan02.html
# WARNING:root:Duplicate or missing URL found: https://www.statmuse.com/nba/player/allen-iverson-1737
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://basketball.realgm.com/nba/teams/Utah-Jazz/29/Playoff-History
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.ncaa.com/news/basketball-men/article/2023-03-09/2023-acc-tournament-bracket-schedule-scores-mens-basketball
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.cbsnews.com/news/most-super-bowl-wins-teams-players/
# WARNING:root:Duplicate or missing URL found: https://www.basketball-reference.com/awards/finals_mvp.html
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/History_of_the_Houston_Rockets
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.eurosport.com/tennis/wimbledon/2022/who-has-won-most-men-s-grand-slam-titles-most-wimbledon-titles-roger-federer-rafael-nadal-novak-djok_sto9013084/story.shtml
# WARNING:root:Duplicate or missing URL found: https://www.eurosport.com/tennis/wimbledon/2022/who-has-won-most-men-s-grand-slam-titles-most-wimbledon-titles-roger-federer-rafael-nadal-novak-djok_sto9013084/story.shtml
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/FIFA_World_Cup
# WARNING:root:Duplicate or missing URL found: https://www.espn.com/nba/team/schedule/_/name/bos
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/List_of_Boston_Celtics_seasons
# WARNING:root:Duplicate or missing URL found: https://www.espn.com/nba/team/_/name/bos/boston-celtics
# WARNING:root:Duplicate or missing URL found: https://www.masterclass.com/articles/how-long-are-basketball-games
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://bleacherreport.com/articles/2072928-ranking-the-most-successful-brothers-in-boxing-history
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Tom_Brady%E2%80%93Peyton_Manning_rivalry
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.espn.com/nba/insider/insider/story/_/id/34348610/nba-projections-2022-23-win-loss-records-brooklyn-nets-boston-celtics-every-eastern-conference-team
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.britannica.com/story/how-fast-is-the-worlds-fastest-human
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.scottfujita.com/how-many-championship-rings-does-steve-kerr-have/
# WARNING:root:Duplicate or missing URL found: https://www.mlb.com/news/teams-with-the-most-world-series-titles-c299893938
# WARNING:root:Duplicate or missing URL found: https://www.mlb.com/news/teams-with-the-most-world-series-titles-c299893938
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.cbssports.com/nba/teams/CHA/charlotte-hornets/stats/regular/
# WARNING:root:Duplicate or missing URL found: https://www.bloomberg.com/graphics/beijing-2022-winter-olympics-medal-count/
# WARNING:root:Duplicate or missing URL found: https://www.thedonutwhole.com/what-years-did-red-wings-win-stanley-cup/
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.thedonutwhole.com/what-years-did-red-wings-win-stanley-cup/
# WARNING:root:Duplicate or missing URL found: https://www.cbssports.com/mma/news/ufc-292-predictions-aljamain-sterling-vs-sean-omalley-fight-card-odds-prelims-preview-expert-picks/
# WARNING:root:Duplicate or missing URL found: https://www.eurosport.com/tennis/wimbledon/2022/who-has-won-most-men-s-grand-slam-titles-most-wimbledon-titles-roger-federer-rafael-nadal-novak-djok_sto9013084/story.shtml
# WARNING:root:Duplicate or missing URL found: https://www.basketball-reference.com/teams/ORL/
# WARNING:root:Duplicate or missing URL found: https://www.basketball-reference.com/teams/ORL/
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://clutchpoints.com/nba/los-angeles-lakers/records
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.si.com/nba/2022/06/16/nba-finals-mvp-photos-michael-jordan-magic-johnson-lebron-james
# WARNING:root:Duplicate or missing URL found: https://www.gurufocus.com/term/deb2equity/MSFT/Debt-to-Equity/MSFT
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/List_of_major_stock_exchanges
# WARNING:root:Duplicate or missing URL found: https://www.visualcapitalist.com/largest-stock-exchanges-in-the-world/
# WARNING:root:Duplicate or missing URL found: https://www.fool.com/investing/stock-market/exchange/nasdaq/
# WARNING:root:Duplicate or missing URL found: https://www.forbes.com/advisor/investing/nasdaq-stock-exchange/
# WARNING:root:Duplicate or missing URL found: https://www.invesco.com/qqq-etf/en/performance.html
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/List_of_Apple_products
# WARNING:root:Duplicate or missing URL found: https://ir.ftandi.com/news-releases/news-release-details/ftai-aviation-ltd-reports-third-quarter-2023-results-declares
# WARNING:root:Duplicate or missing URL found: https://infonewt.com/apple-release-patterns
# WARNING:root:Duplicate or missing URL found: https://www.theglobeandmail.com/investing/markets/inside-the-market/market-news/article-premarket-tsx-eyes-higher-open-on-last-trading-day-of-the-year/
# WARNING:root:Duplicate or missing URL found: https://www.bankrate.com/taxes/quick-tax-rate-calculator/
# WARNING:root:Duplicate or missing URL found: https://taxfoundation.org/data/all/federal/2023-tax-brackets/
# WARNING:root:Duplicate or missing URL found: https://www.computerworld.com/article/3685936/tech-layoffs-in-2023-a-timeline.html
# WARNING:root:Duplicate or missing URL found: https://www.cnbc.com/2024/01/12/microsoft-tops-apple-in-market-cap-at-fridays-close.html
# WARNING:root:Duplicate or missing URL found: https://turbotax.intuit.com/tax-tools/calculators/tax-bracket/
# WARNING:root:Duplicate or missing URL found: https://www.nerdwallet.com/taxes/tax-calculator
# WARNING:root:Duplicate or missing URL found: https://www.ramseysolutions.com/retirement/traditional-401k-vs-roth-401k
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Fortune_500
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: None
# WARNING:root:Duplicate or missing URL found: https://www.stockinvestor.com/stock-price-quote-and-latest-news/dhcni/
# WARNING:root:Duplicate or missing URL found: https://www.ranker.com/crowdranked-list/best-movies-of-1994
# WARNING:root:Duplicate or missing URL found: https://www.nytimes.com/2024/02/14/movies/bob-marley-one-love-review.html
# WARNING:root:Duplicate or missing URL found: https://www.nytimes.com/2024/02/14/movies/bob-marley-one-love-review.html
# WARNING:root:Duplicate or missing URL found: https://www.soapcentral.com/theactors/tamblyn_amber.php
# WARNING:root:Duplicate or missing URL found: https://www.soapcentral.com/theactors/tamblyn_amber.php
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Eastbound_%26_Down
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Die_Hard
# WARNING:root:Duplicate or missing URL found: https://www.themarysue.com/how-long-lord-of-the-rings-hobbit-films/
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Jurassic_Park
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Jurassic_Park
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/DreamWorks_Pictures
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/DreamWorks_Pictures
# WARNING:root:Duplicate or missing URL found: https://www.biography.com/actors/leonardo-dicaprio
# WARNING:root:Duplicate or missing URL found: https://people.com/movies/actors-and-their-stunt-doubles-photos/
# WARNING:root:Duplicate or missing URL found: https://www.boxofficemojo.com/title/tt0076759/
# WARNING:root:Duplicate or missing URL found: https://www.themarysue.com/how-long-lord-of-the-rings-hobbit-films/
# WARNING:root:Duplicate or missing URL found: https://www.dickwizardry.com/articles/the-difference-between-theatrical-and-extended-edition-lord-of-the-rings
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/The_Adventures_of_Sharkboy_and_Lavagirl_in_3-D
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/The_Adventures_of_Sharkboy_and_Lavagirl_in_3-D
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Life_Stinks
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Life_Stinks
# WARNING:root:Duplicate or missing URL found: https://www.amazon.com/dp/B00005K3NZ/ref=tsm_1_fb_lk
# WARNING:root:Duplicate or missing URL found: https://disney.fandom.com/wiki/Toy_Story_(franchise)
# WARNING:root:Duplicate or missing URL found: https://www.latimes.com/entertainment/movies/la-ca-mn-sneaks-greatest-showman-songs-20171103-story.html
# WARNING:root:Duplicate or missing URL found: https://www.latimes.com/entertainment/movies/la-ca-mn-sneaks-greatest-showman-songs-20171103-story.html
# WARNING:root:Duplicate or missing URL found: https://www.cbr.com/best-movies-box-office-bombs/
# WARNING:root:Duplicate or missing URL found: https://www.britannica.com/topic/Wonder-Woman
# WARNING:root:Duplicate or missing URL found: https://deadline.com/2023/06/box-office-spider-man-across-the-spider-verse-1235398807/
# WARNING:root:Duplicate or missing URL found: https://www.forbes.com/sites/scottmendelson/2020/08/13/harry-potter-movies-ranked-box-office-jk-rowling-emma-watson-daniel-radcliffe/
# WARNING:root:Duplicate or missing URL found: https://www.the-numbers.com/movies/franchise/Harry-Potter
# WARNING:root:Duplicate or missing URL found: https://www.statista.com/statistics/323356/harry-potter-production-costs-box-office-revenue/
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/The_Hatton_Garden_Job
# WARNING:root:Duplicate or missing URL found: https://www.independent.co.uk/arts-entertainment/films/news/shawshank-redemption-imdb-top-250-best-movie-frank-darabont-films-godfather-morgan-freeman-a9100431.html
# WARNING:root:Duplicate or missing URL found: https://en.wikipedia.org/wiki/Judas_and_the_Black_Messiah
# WARNING:root:Duplicate or missing URL found: https://www.wkyc.com/article/entertainment/judas-and-the-black-messiah-academy-awards/95-7142ac60-b239-4205-bbb2-23f810478a45
# 144
# 71
# 144

# %%
# save documents to jsonl
filename = os.path.join(data_dir, "documents_{}.jsonl")

save_documents_as_jsonl(
    documents=documents_sports,
    output_path=filename.format("sports")
)

save_documents_as_jsonl(
    documents=documents_finance,
    output_path=filename.format("finance")
)

save_documents_as_jsonl(
    documents=documents_movie,
    output_path=filename.format("movie")
)
